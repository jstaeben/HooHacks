# %%
# Python ≥3.5 is required
#import sys #
# Scikit-Learn ≥0.20 is required
import sklearn # general ml package

# Common imports
import numpy as np # fundamental package for scientific computing
import os # to run file I/O operation 

# to make this notebook's output stable across runs
# any number will do, as long as it is used consistently
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
  """Save the selected figure into disc under an image extention and resolution

  Parameters
  ----------
  fig_id : figure handle
    The id number of the figure
  tight_layout : boolean (True or False)
    Specifies whenther the layout should be tight or not
  fig_extension: string
    Under what extension should the file be saved ("png" or "jpg")
  resolution: int
    the quality of the figure (ie. 100,200,300)

  Returns
  -------
  void
    Does not return any value
  """

  path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
  print("Saving figure", fig_id)
  if tight_layout:
    plt.tight_layout()
  plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import pandas as pd

housing = pd.read_csv("housing.csv")

# %%
housing.head(10)
# Out:
#            id                                                url  ...     long state
# 0  7049044568  https://reno.craigslist.org/apa/d/reno-beautif...  ... -119.796    ca
# 1  7049047186  https://reno.craigslist.org/apa/d/reno-reduced...  ... -119.789    ca
# 2  7043634882  https://reno.craigslist.org/apa/d/sparks-state...  ... -119.708    ca
# 3  7049045324  https://reno.craigslist.org/apa/d/reno-1x1-fir...  ... -119.771    ca
# 4  7049043759  https://reno.craigslist.org/apa/d/reno-no-long...  ... -119.805    ca
# 5  7046327064  https://reno.craigslist.org/apa/d/reno-walk-in...  ... -119.776    ca
# 6  7049020738  https://reno.craigslist.org/apa/d/1-bedroom-av...  ... -119.802    ca
# 7  7049041899  https://reno.craigslist.org/apa/d/reno-1x1-fir...  ... -119.771    ca
# 8  7049041451  https://reno.craigslist.org/apa/d/sparks-bouti...  ... -119.672    ca
# 9  7049041434  https://reno.craigslist.org/apa/d/reno-6850-sh...  ... -119.897    ca
#
# [10 rows x 22 columns]

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384977 entries, 0 to 384976
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       384977 non-null  int64
#  1   url                      384977 non-null  object
#  2   region                   384977 non-null  object
#  3   region_url               384977 non-null  object
#  4   price                    384977 non-null  int64
#  5   type                     384977 non-null  object
#  6   sqfeet                   384977 non-null  int64
#  7   beds                     384977 non-null  int64
#  8   baths                    384977 non-null  float64
#  9   cats_allowed             384977 non-null  int64
#  10  dogs_allowed             384977 non-null  int64
#  11  smoking_allowed          384977 non-null  int64
#  12  wheelchair_access        384977 non-null  int64
#  13  electric_vehicle_charge  384977 non-null  int64
#  14  comes_furnished          384977 non-null  int64
#  15  laundry_options          305951 non-null  object
#  16  parking_options          244290 non-null  object
#  17  image_url                384977 non-null  object
#  18  description              384975 non-null  object
#  19  lat                      383059 non-null  float64
#  20  long                     383059 non-null  float64
#  21  state                    384977 non-null  object
# dtypes: float64(3), int64(10), object(9)
# memory usage: 64.6+ MB

# %%
# Provide some basic statistics about the dataset
housing.describe()
# Out:
#                  id         price  ...            lat           long
# count  3.849770e+05  3.849770e+05  ...  383059.000000  383059.000000
# mean   7.040982e+09  8.825722e+03  ...      37.233487     -92.700631
# std    8.800376e+06  4.462200e+06  ...       5.546171      16.531980
# min    7.003808e+09  0.000000e+00  ...     -43.533300    -163.894000
# 25%    7.035979e+09  8.050000e+02  ...      33.454700    -100.775000
# 50%    7.043320e+09  1.036000e+03  ...      37.647800     -87.745100
# 75%    7.048426e+09  1.395000e+03  ...      41.138300     -81.179600
# max    7.051292e+09  2.768307e+09  ...     102.036000     172.633000
#
# [8 rows x 13 columns]

# %%
from pandas.plotting import scatter_matrix # optional
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt

housing.plot(kind="scatter", x="long", y="lat", alpha=0.4,
    s=housing["price"]/1000, label="price", figsize=(10,7),
    c="wheelchair_access", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.ylim(15, 55)
plt.xlim(-130, -60)
plt.legend()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
housing.hist(figsize=(20,15))
plt.show()

# %%
from sklearn.model_selection import train_test_split
# Split the data into train set (80%) and test set (20%)
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# %%
# Make a copy of the stratified train set
housing = train_set.copy()

# %%
# Add alpha channel for transparent so that the plot is less crowded.
housing.plot(kind="scatter", x="sqfeet", y="price", alpha=0.3)
# save_fig("better_visualization_plot")

# %%
# Incorporate the population into the circle size
# Add color (jet map) for the value of the housing
housing.plot(kind="scatter", x="sqfeet", y="price", alpha=0.4,
    s=housing["beds"]*10, label="dis", figsize=(10,7), cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()
# save_fig("housing_prices_scatterplot")

# %%
# Let's look at how much each feature correlates to the house value 
corr_matrix = housing.corr()
corr_matrix["price"].sort_values(ascending=False)
# Out:
# price                      1.000000
# baths                      0.008339
# wheelchair_access          0.006665
# beds                       0.001594
# comes_furnished            0.001019
# electric_vehicle_charge    0.000514
# sqfeet                     0.000268
# id                        -0.000210
# long                      -0.000424
# smoking_allowed           -0.000803
# cats_allowed              -0.001654
# dogs_allowed              -0.002272
# lat                       -0.002530
# Name: price, dtype: float64

# %%
# from pandas.tools.plotting import scatter_matrix # For older versions of Pandas
from pandas.plotting import scatter_matrix

attributes = ["price", "sqfeet", "beds",
              "baths"]
scatter_matrix(housing[attributes], figsize=(12, 8))
# save_fig("scatter_matrix_plot")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d4376250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d2b62890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d2b19f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d2bdd5d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d40d2c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d3f97310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d2b8da10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d4304fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d4310050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d42c67d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d423d410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d4273a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d4235150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d41e97d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d41a2e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7d4165510>]],
#       dtype=object)

# %%
# Create the features and labels for training
housing = strat_train_set.drop("price", axis=1) # drop labels for training set
housing_labels = strat_train_set["price"].copy()

housing_test = strat_test_set.drop("price", axis=1)
housing_labels_test = strat_test_set["price"].copy()

# %% [markdown]
# Here we have our pipeline so our data will be ready to feed into a model

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="median")),
        #('attribs_adder', CombinedAttributesAdder()),
        ('std_scaler', StandardScaler()),
    ])

housing_tr = num_pipeline.fit_transform(housing)

# %% [markdown]
# We unfortunately ran out of time, but this would be where we train a model to predict housing prices
